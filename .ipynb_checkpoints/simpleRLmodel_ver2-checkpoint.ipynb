# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import mplfinance as mpf

# Stable-Baselines3 imports
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv  # Use this instead of DummyVecEnv

# Gymnasium (updated from Gym)
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box

# %%
# Load Data
df = pd.read_csv("MGOL_data.xml.csv")  # Replace with actual file
df['datetime'] = pd.to_datetime(df['datetime'], format='%m/%d/%y %H:%M')
df.set_index('datetime', inplace=True)

# %%
df.index = df.index + pd.Timedelta(hours=3)
df.index.name = 'Date'
df = df.drop(columns=['symbol', 'frame'])

# %%
import pandas as pd
import numpy as np
import gymnasium as gym
from gym import Env
from gym.spaces import Discrete, Box

class TradingEnv(Env):
    def __init__(self, df):
        super(TradingEnv, self).__init__()
        self.df = df
        self.current_step = 0
        self.balance = 10000  # Starting cash
        self.shares = 0
        self.total_reward = 0
        self.position_open = False  # Track open positions
        self.round_trip_trades = 0  # Counter for buy-sell cycles

        # Action Space: 0 = Hold, 1 = Buy, 2 = Sell
        self.action_space = Discrete(3)

        # Observation Space: Open, High, Low, Close, Volume
        self.observation_space = Box(
            low=-np.inf, high=np.inf, shape=(5,), dtype=np.float32
        )

    def step(self, action):
        if self.current_step >= len(self.df) - 1:
            return np.zeros(self.observation_space.shape), 0, True, False, {}
        
        current_price = self.df.iloc[self.current_step]["close"]
        reward = 0
        done = False
        truncated = False

        if action == 1:  # Buy
            if self.balance >= current_price and not self.position_open:
                self.shares = 1
                self.balance -= current_price
                self.position_open = True  # Prevents another buy before a sell
                reward = -0.01  # Small penalty to avoid random buying
                self.round_trip_trades += 1

        elif action == 2:  # Sell
            if self.shares == 1 and self.position_open:
                self.shares = 0
                self.balance += current_price
                reward = (current_price - self.df.iloc[self.current_step - 1]['close']) * 10  # Reward profit
                self.position_open = False  # Allows buying again

        else:  # Action 0: Hold
            reward -= 0.005  # Small penalty per timestep for holding
        
        # Terminate after 10 round-trip trades or end of data
        if self.round_trip_trades >= 10:
            done = True
        if self.current_step >= len(self.df) - 1:
            done = True

        self.current_step += 1
        obs = self.df.iloc[self.current_step][["open", "high", "low", "close", "volume"]].values
        info = {}

        return obs, reward, done, truncated, info

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.balance = 10000
        self.shares = 0
        self.position_open = False
        self.round_trip_trades = 0
        obs = self.df.iloc[self.current_step][["open", "high", "low", "close", "volume"]].values
        return obs, {}

# %%
import pandas as pd
import numpy as np
from gym import Env
from gym.spaces import Discrete, Box

# Load Data
df = pd.read_csv("MGOL_data.xml.csv")  # Replace with actual file
df['datetime'] = pd.to_datetime(df['datetime'], format='%m/%d/%y %H:%M')
df.set_index('datetime', inplace=True)

# Custom Trading Environment
class TradingEnv(Env):
    def __init__(self, df):
        super(TradingEnv, self).__init__()
        self.df = df
        self.current_step = 0
        self.balance = 10000  # Starting cash
        self.shares = 0
        self.total_reward = 0

        # Action Space: 0 = Hold, 1 = Buy, 2 = Sell
        self.action_space = Discrete(3)

        # Observation Space: Open, High, Low, Close, Volume
        self.observation_space = Box(
            low=-np.inf, high=np.inf, shape=(5,), dtype=np.float32
        )

    def step(self, action):
        current_price = self.df.iloc[self.current_step]['close']  # Use correct column name
        reward = 0
        done = False
        truncated = False  # Gym v0.26+ requires `truncated` in addition to `done`

        if action == 1:  # Buy
            if self.balance >= current_price:
                self.shares += 1
                self.balance -= current_price
        elif action == 2:  # Sell
            if self.shares > 0:
                self.shares -= 1
                self.balance += current_price
                reward = current_price - self.df.iloc[self.current_step - 1]['close']  # Use correct column name

        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            done = True  # End of data

        # Get the next observation
        obs = self.df.iloc[self.current_step][['open', 'high', 'low', 'close', 'volume']].values  # Use correct column names
        info = {}  # Additional info (can be used for debugging or logging)

        return obs, reward, done, truncated, info  # Gym v0.26+ requires 5 return values

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)  # Required for Gym v0.26+
        self.current_step = 0
        self.balance = 10000
        self.shares = 0
        observation = self.df.iloc[self.current_step][['open', 'high', 'low', 'close', 'volume']].values  # Use correct column names
        info = {}  # Return an empty info dictionary
        return observation, info

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import DummyVecEnv
import pandas as pd

# Initialize dictionaries to store buy and sell signals
buy_signals_1000 = []
sell_signals_1000 = []
buy_signals_10000 = []
sell_signals_10000 = []
buy_signals_100000 = []
sell_signals_100000 = []

# Initialize the environment and model
env = TradingEnv(df)  # Replace `TradingEnv` with your custom environment
env = DummyVecEnv([lambda: env])  # Wrap the environment for vectorized operations

# Define the PPO model
model = PPO(
    policy="MlpPolicy",  # Policy network
    env=env,             # Environment
    verbose=1,           # Print training logs
    learning_rate=3e-4,  # Learning rate
    n_steps=min(len(df) // 2, 512),        # Number of steps per update
    batch_size=64,       # Batch size
    n_epochs=10,         # Number of epochs per update
    gamma=0.99,          # Discount factor
    gae_lambda=0.95,     # GAE parameter
    clip_range=0.2,      # PPO clip range
    ent_coef=0.01,        # Entropy coefficient
    max_grad_norm=0.5,   # Gradient clipping
)

# Save the trained model (optional)
model.save("ppo_model")

# Function to simulate and record buy/sell signals
def simulate_and_record_signals(num_timesteps, buy_signals_list, sell_signals_list):
    # Train the model for the specified number of timesteps
    model.learn(total_timesteps=num_timesteps)

    # Simulate trades
    obs = env.reset()  # Reset the environment
    done = False  # Flag to track if the episode is done

    while not done:
        action, _ = model.predict(obs)  # Predict action (Buy, Sell, or Hold)
        action = action[0]  # Extract the action from the batch (DummyVecEnv)

        # Record buy or sell signals
        current_step = env.get_attr('current_step')[0]  # Get the current step index
        if action == 1:  # Buy signal
            buy_signals_list.append(df.index[current_step])
        elif action == 2:  # Sell signal
            sell_signals_list.append(df.index[current_step])

        # Take action in the environment
        obs, reward, done, info = env.step([action])  # Step through the environment

        # End the episode if done
        if done:
            break
# Out:
# Using cpu device
# /Users/larka/jupyter_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /Users/larka/jupyter_env/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 480`, after every 7 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=480 and n_envs=1)
#   warnings.warn(

# %%
# Run simulation for 1000 timesteps
simulate_and_record_signals(1000, buy_signals_1000, sell_signals_1000)

# Run simulation for 10000 timesteps
simulate_and_record_signals(10000, buy_signals_10000, sell_signals_10000)

# Run simulation for 10000 timesteps
simulate_and_record_signals(100000, buy_signals_100000, sell_signals_100000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1990 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 480  |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1870        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 960         |
# | train/                  |             |
# |    approx_kl            | 0.012026766 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00958    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 0.0221      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1961         |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1440         |
# | train/                  |              |
# |    approx_kl            | 0.0090348255 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -3.47e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00274     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 0.0167       |
# ------------------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3419 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 480  |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2746        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 960         |
# | train/                  |             |
# |    approx_kl            | 0.013705001 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | -0.00191    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0619      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2566        |
# |    iterations           | 3           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 1440        |
# | train/                  |             |
# |    approx_kl            | 0.007293882 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | -0.000622   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 0.00502     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2479        |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.016087476 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -0.000324   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 0.00484     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2440        |
# |    iterations           | 5           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2400        |
# | train/                  |             |
# |    approx_kl            | 0.004512492 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.000123   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 0.00312     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2417        |
# |    iterations           | 6           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2880        |
# | train/                  |             |
# |    approx_kl            | 0.012219904 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -5.09e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000857   |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2405        |
# |    iterations           | 7           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3360        |
# | train/                  |             |
# |    approx_kl            | 0.013330655 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | -6.88e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0718     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0098     |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2391         |
# |    iterations           | 8            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0029896642 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | -0.000499    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000388    |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 7.97e-05     |
# |    value_loss           | 0.00458      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2361        |
# |    iterations           | 9           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4320        |
# | train/                  |             |
# |    approx_kl            | 0.016273107 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | -0.000494   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2338         |
# |    iterations           | 10           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 0.0032858998 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 4.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0166      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000179    |
# |    value_loss           | 0.00439      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2337        |
# |    iterations           | 11          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 5280        |
# | train/                  |             |
# |    approx_kl            | 0.013654313 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | -0.000244   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2335        |
# |    iterations           | 12          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 0.006766431 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | -0.000621   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0245     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.00313     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2333       |
# |    iterations           | 13         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 6240       |
# | train/                  |            |
# |    approx_kl            | 0.01059109 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.73      |
# |    explained_variance   | -3.29e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.014     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00484   |
# |    value_loss           | 0.0046     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2201         |
# |    iterations           | 14           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6720         |
# | train/                  |              |
# |    approx_kl            | 0.0085640615 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | -0.000423    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00261     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 0.00459      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2162         |
# |    iterations           | 15           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 7200         |
# | train/                  |              |
# |    approx_kl            | 0.0017210025 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | -0.000567    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00346      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.00381      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2151         |
# |    iterations           | 16           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0022917942 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | -0.00105     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00114     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000912    |
# |    value_loss           | 0.00288      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2144         |
# |    iterations           | 17           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8160         |
# | train/                  |              |
# |    approx_kl            | 0.0012769239 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | -0.000361    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0142      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.000551     |
# |    value_loss           | 0.00194      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2151       |
# |    iterations           | 18         |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 8640       |
# | train/                  |            |
# |    approx_kl            | 0.00613399 |
# |    clip_fraction        | 0.0383     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.551     |
# |    explained_variance   | -0.000467  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000628  |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00392   |
# |    value_loss           | 0.00319    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2155        |
# |    iterations           | 19          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 9120        |
# | train/                  |             |
# |    approx_kl            | 0.003126558 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | -0.000536   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00944     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2159         |
# |    iterations           | 20           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0016016997 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | -0.000132    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0242      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000206    |
# |    value_loss           | 0.0026       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2166         |
# |    iterations           | 21           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10080        |
# | train/                  |              |
# |    approx_kl            | 0.0031828554 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | -0.000167    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0156      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3471 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 480  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2746         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 960          |
# | train/                  |              |
# |    approx_kl            | 0.0021648295 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | -0.00148     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 0.00184      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2273         |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1440         |
# | train/                  |              |
# |    approx_kl            | 0.0024333834 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0177      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00089     |
# |    value_loss           | 0.00168      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2276         |
# |    iterations           | 4            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0020884264 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | 9.83e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0128       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000278     |
# |    value_loss           | 0.00183      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2285         |
# |    iterations           | 5            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 0.0045324205 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.000292     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000755     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00833     |
# |    value_loss           | 0.00193      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2290         |
# |    iterations           | 6            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2880         |
# | train/                  |              |
# |    approx_kl            | 0.0030060513 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.00302      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2282         |
# |    iterations           | 7            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 3360         |
# | train/                  |              |
# |    approx_kl            | 0.0032887869 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.405       |
# |    explained_variance   | 0.00978      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00234     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 0.00114      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2263         |
# |    iterations           | 8            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0019157521 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.342       |
# |    explained_variance   | 0.0228       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00284     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 0.00141      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2268        |
# |    iterations           | 9           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4320        |
# | train/                  |             |
# |    approx_kl            | 0.002532666 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 0.0519      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00865    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00782    |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2258          |
# |    iterations           | 10            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 4800          |
# | train/                  |               |
# |    approx_kl            | 0.00029031653 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.328        |
# |    explained_variance   | -0.0219       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0035        |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.00023      |
# |    value_loss           | 0.0186        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2245         |
# |    iterations           | 11           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 5280         |
# | train/                  |              |
# |    approx_kl            | 0.0014573231 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 4.64e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000754    |
# |    value_loss           | 0.00109      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2242         |
# |    iterations           | 12           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 5760         |
# | train/                  |              |
# |    approx_kl            | 0.0004921687 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 2.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00211     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 0.00157      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2112         |
# |    iterations           | 13           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6240         |
# | train/                  |              |
# |    approx_kl            | 0.0007646333 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.285       |
# |    explained_variance   | -0.00155     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0126      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 0.00044      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2116         |
# |    iterations           | 14           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6720         |
# | train/                  |              |
# |    approx_kl            | 0.0014820521 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.00014      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2123        |
# |    iterations           | 15          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.001345246 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | -0.000135   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00635     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 0.0205      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2129         |
# |    iterations           | 16           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0009354841 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | -0.00526     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00125     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 0.00273      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2137         |
# |    iterations           | 17           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8160         |
# | train/                  |              |
# |    approx_kl            | 0.0005425026 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | -0.00159     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00196     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 0.000611     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2142         |
# |    iterations           | 18           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8640         |
# | train/                  |              |
# |    approx_kl            | 0.0011471737 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.188       |
# |    explained_variance   | -7.4e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00166     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 0.00094      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2148         |
# |    iterations           | 19           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 9120         |
# | train/                  |              |
# |    approx_kl            | 0.0006189897 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | 0.00025      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00136     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.000486     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2152         |
# |    iterations           | 20           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0005922528 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.144       |
# |    explained_variance   | -0.000256    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00378      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 0.000375     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2154         |
# |    iterations           | 21           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10080        |
# | train/                  |              |
# |    approx_kl            | 0.0007554471 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.124       |
# |    explained_variance   | 0.000158     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000233    |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 0.00206      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2159         |
# |    iterations           | 22           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10560        |
# | train/                  |              |
# |    approx_kl            | 2.096896e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.112       |
# |    explained_variance   | -0.000549    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000593     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 9.74e-05     |
# |    value_loss           | 0.000242     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2165         |
# |    iterations           | 23           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 11040        |
# | train/                  |              |
# |    approx_kl            | 0.0001287678 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.000162     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0086      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -8.84e-05    |
# |    value_loss           | 0.000769     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2171         |
# |    iterations           | 24           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | 0.0014310215 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.125       |
# |    explained_variance   | 0.000918     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0167      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 0.000543     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2171         |
# |    iterations           | 25           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0008744373 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | -0.000866    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00518     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.000559     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2174         |
# |    iterations           | 26           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12480        |
# | train/                  |              |
# |    approx_kl            | 0.0004696967 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.000864     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00573     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.00081      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2171          |
# |    iterations           | 27            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 12960         |
# | train/                  |               |
# |    approx_kl            | 0.00026291213 |
# |    clip_fraction        | 0.00918       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | -0.00298      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000829     |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.0018       |
# |    value_loss           | 0.000416      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2172          |
# |    iterations           | 28            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 13440         |
# | train/                  |               |
# |    approx_kl            | 0.00023990404 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.125        |
# |    explained_variance   | 6.13e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00687      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.000226      |
# |    value_loss           | 0.000353      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2174          |
# |    iterations           | 29            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 13920         |
# | train/                  |               |
# |    approx_kl            | 0.00011584384 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.13         |
# |    explained_variance   | -8.94e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00116      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | 0.000258      |
# |    value_loss           | 0.000516      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2171          |
# |    iterations           | 30            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 14400         |
# | train/                  |               |
# |    approx_kl            | 0.00060075254 |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.116        |
# |    explained_variance   | -0.000838     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00107      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.00232      |
# |    value_loss           | 0.000412      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2175         |
# |    iterations           | 31           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14880        |
# | train/                  |              |
# |    approx_kl            | 0.0001415431 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | -1.99e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00145     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 3.79e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2178         |
# |    iterations           | 32           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0009531565 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.134       |
# |    explained_variance   | -0.000238    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0199      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 0.000549     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2182          |
# |    iterations           | 33            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 15840         |
# | train/                  |               |
# |    approx_kl            | 0.00089123787 |
# |    clip_fraction        | 0.0197        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.115        |
# |    explained_variance   | -2.66e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0158       |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.00519      |
# |    value_loss           | 0.000705      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2185          |
# |    iterations           | 34            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 16320         |
# | train/                  |               |
# |    approx_kl            | 0.00025982945 |
# |    clip_fraction        | 0.00645       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.101        |
# |    explained_variance   | -0.000134     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000485     |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.00244      |
# |    value_loss           | 0.0006        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2187          |
# |    iterations           | 35            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 16800         |
# | train/                  |               |
# |    approx_kl            | 2.2637658e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | -1.43e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00401       |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -7.69e-05     |
# |    value_loss           | 0.000872      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2189         |
# |    iterations           | 36           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 17280        |
# | train/                  |              |
# |    approx_kl            | 0.0004736319 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | -0.0057      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000509    |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 0.000602     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2189          |
# |    iterations           | 37            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 17760         |
# | train/                  |               |
# |    approx_kl            | 0.00020547013 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.116        |
# |    explained_variance   | -0.00275      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.02         |
# |    n_updates            | 600           |
# |    policy_gradient_loss | 0.000764      |
# |    value_loss           | 0.000263      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2190          |
# |    iterations           | 38            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 18240         |
# | train/                  |               |
# |    approx_kl            | 0.00044907338 |
# |    clip_fraction        | 0.00996       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0317       |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -0.0047       |
# |    value_loss           | 0.000171      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2190          |
# |    iterations           | 39            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 18720         |
# | train/                  |               |
# |    approx_kl            | 0.00045988522 |
# |    clip_fraction        | 0.00273       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0878       |
# |    explained_variance   | -0.00351      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000712     |
# |    n_updates            | 620           |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 0.000339      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2152          |
# |    iterations           | 40            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 19200         |
# | train/                  |               |
# |    approx_kl            | 0.00016199693 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0749       |
# |    explained_variance   | 0.0595        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000691     |
# |    n_updates            | 630           |
# |    policy_gradient_loss | 6.77e-05      |
# |    value_loss           | 7.29e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2129          |
# |    iterations           | 41            |
# |    time_elapsed         | 9             |
# ...
# |    iterations           | 189           |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 90720         |
# | train/                  |               |
# |    approx_kl            | 0.00056089286 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0662       |
# |    explained_variance   | -0.00116      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000539     |
# |    n_updates            | 2120          |
# |    policy_gradient_loss | -0.00178      |
# |    value_loss           | 0.000222      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2232         |
# |    iterations           | 190          |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 91200        |
# | train/                  |              |
# |    approx_kl            | 0.0011508339 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0498      |
# |    explained_variance   | -0.105       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000478    |
# |    n_updates            | 2130         |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 3.88e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2232         |
# |    iterations           | 191          |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 91680        |
# | train/                  |              |
# |    approx_kl            | 0.0006444305 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0368      |
# |    explained_variance   | 0.000996     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000294    |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 5.18e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2233          |
# |    iterations           | 192           |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 2.7122209e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0355       |
# |    explained_variance   | -0.0395       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0003       |
# |    n_updates            | 2150          |
# |    policy_gradient_loss | 1.25e-05      |
# |    value_loss           | 0.000103      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2234          |
# |    iterations           | 193           |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 92640         |
# | train/                  |               |
# |    approx_kl            | 0.00015170535 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0442       |
# |    explained_variance   | -0.544        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000477     |
# |    n_updates            | 2160          |
# |    policy_gradient_loss | -0.0014       |
# |    value_loss           | 3.13e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2234         |
# |    iterations           | 194          |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 93120        |
# | train/                  |              |
# |    approx_kl            | 0.0001394715 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0432      |
# |    explained_variance   | 0.018        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000385    |
# |    n_updates            | 2170         |
# |    policy_gradient_loss | -0.000848    |
# |    value_loss           | 6e-05        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2235         |
# |    iterations           | 195          |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 93600        |
# | train/                  |              |
# |    approx_kl            | 0.0006546682 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.032       |
# |    explained_variance   | -0.00936     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000291    |
# |    n_updates            | 2180         |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 1.11e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2235         |
# |    iterations           | 196          |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 94080        |
# | train/                  |              |
# |    approx_kl            | 0.0001341931 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0351      |
# |    explained_variance   | -0.109       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000376    |
# |    n_updates            | 2190         |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 1.63e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2235          |
# |    iterations           | 197           |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 94560         |
# | train/                  |               |
# |    approx_kl            | 0.00012843579 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0417       |
# |    explained_variance   | 0.000916      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000202     |
# |    n_updates            | 2200          |
# |    policy_gradient_loss | -0.000861     |
# |    value_loss           | 0.000519      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2235          |
# |    iterations           | 198           |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 95040         |
# | train/                  |               |
# |    approx_kl            | 0.00075906294 |
# |    clip_fraction        | 0.00801       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0319       |
# |    explained_variance   | 0.0471        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000295     |
# |    n_updates            | 2210          |
# |    policy_gradient_loss | -0.00311      |
# |    value_loss           | 3.51e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2235          |
# |    iterations           | 199           |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 95520         |
# | train/                  |               |
# |    approx_kl            | 0.00043101865 |
# |    clip_fraction        | 0.00352       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0244       |
# |    explained_variance   | -0.069        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000234     |
# |    n_updates            | 2220          |
# |    policy_gradient_loss | -0.00312      |
# |    value_loss           | 1.52e-06      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2236      |
# |    iterations           | 200       |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 96000     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0237   |
# |    explained_variance   | 0.0856    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000241 |
# |    n_updates            | 2230      |
# |    policy_gradient_loss | -1.2e-07  |
# |    value_loss           | 5.55e-07  |
# ---------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2236           |
# |    iterations           | 201            |
# |    time_elapsed         | 43             |
# |    total_timesteps      | 96480          |
# | train/                  |                |
# |    approx_kl            | 0.000104186125 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.022         |
# |    explained_variance   | 0.000126       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 9.52e-05       |
# |    n_updates            | 2240           |
# |    policy_gradient_loss | -0.00046       |
# |    value_loss           | 0.000504       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2237          |
# |    iterations           | 202           |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 96960         |
# | train/                  |               |
# |    approx_kl            | 0.00045418763 |
# |    clip_fraction        | 0.00566       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0163       |
# |    explained_variance   | 0.0785        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000152     |
# |    n_updates            | 2250          |
# |    policy_gradient_loss | -0.0036       |
# |    value_loss           | 1.08e-05      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2237      |
# |    iterations           | 203       |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 97440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0154   |
# |    explained_variance   | -3.2      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000155 |
# |    n_updates            | 2260      |
# |    policy_gradient_loss | -3.41e-08 |
# |    value_loss           | 8.22e-08  |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2238          |
# |    iterations           | 204           |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 97920         |
# | train/                  |               |
# |    approx_kl            | 0.00017795525 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0127       |
# |    explained_variance   | 0.0185        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000113     |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -0.00189      |
# |    value_loss           | 1.52e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2238          |
# |    iterations           | 205           |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 98400         |
# | train/                  |               |
# |    approx_kl            | 0.00010889943 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00953      |
# |    explained_variance   | -0.195        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -8.99e-05     |
# |    n_updates            | 2280          |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 4.43e-07      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2239      |
# |    iterations           | 206       |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 98880     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00906  |
# |    explained_variance   | -0.0212   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.12e-05 |
# |    n_updates            | 2290      |
# |    policy_gradient_loss | -6.51e-09 |
# |    value_loss           | 2.79e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2239      |
# |    iterations           | 207       |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 99360     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0092   |
# |    explained_variance   | -3.22     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.26e-05 |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | 2.48e-08  |
# |    value_loss           | 1.52e-08  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2240      |
# |    iterations           | 208       |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 99840     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00935  |
# |    explained_variance   | -0.0652   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.46e-05 |
# |    n_updates            | 2310      |
# |    policy_gradient_loss | -1.27e-08 |
# |    value_loss           | 2.71e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2240      |
# |    iterations           | 209       |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 100320    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00951  |
# |    explained_variance   | -3.51     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.58e-05 |
# |    n_updates            | 2320      |
# |    policy_gradient_loss | -1.39e-08 |
# |    value_loss           | 6.1e-09   |
# ---------------------------------------

# %%
import mplfinance as mpf
import matplotlib.dates as mdates
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame, buy_signals_1000, sell_signals_1000, buy_signals_10000, and sell_signals_10000 are your lists of timestamps

# Function to plot the signals for a given buy and sell signal list
def plot_signals(buy_signals, sell_signals, title):
    # Convert buy/sell signals to DatetimeIndex
    buy_signals = pd.to_datetime(buy_signals)  
    buy_signals = buy_signals[buy_signals.isin(df.index)]  # Filter buy signals to match df.index

    sell_signals = pd.to_datetime(sell_signals)  
    sell_signals = sell_signals[sell_signals.isin(df.index)]  # Filter sell signals to match df.index

    # Create new columns to mark the buy and sell signals with NaN for non-signals
    buy_signal_prices = df['close'].copy()
    buy_signal_prices[~df.index.isin(buy_signals)] = float('nan')  # Set non-buy signals to NaN
    
    sell_signal_prices = df['close'].copy()
    sell_signal_prices[~df.index.isin(sell_signals)] = float('nan')  # Set non-sell signals to NaN

    # Create addplots for buy and sell signals
    buy_signal_plot = mpf.make_addplot(buy_signal_prices, type='scatter', markersize=40, marker='^', color='green')
    sell_signal_plot = mpf.make_addplot(sell_signal_prices, type='scatter', markersize=40, marker='v', color='red')

    # Plot with the added buy and sell signals
    fig, axes = mpf.plot(
        df,
        type='ohlc',
        style='charles',
        datetime_format='%Y-%m-%d %H:%M',
        addplot=[buy_signal_plot, sell_signal_plot],
        returnfig=True,
        figsize=(16, 8),
        warn_too_much_data=10000,
        title=title #Adjust the size again to maintain consistency
    )

    #plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    # Add legend manually
    #plt.legend(['Buy Signals', 'Sell Signals'], loc='upper left')

    # Add title
    #plt.title(title)

    # Show the plot
    #plt.show()

# Plot for 1000 timesteps signals
plot_signals(buy_signals_1000, sell_signals_1000, title="Buy/Sell Signals for 1000 Timesteps")

# Plot for 10000 timesteps signals
plot_signals(buy_signals_10000, sell_signals_10000, title="Buy/Sell Signals for 10000 Timesteps")

# Plot for 100000 timesteps signals
#plot_signals(buy_signals_100000, sell_signals_100000, title="Buy/Sell Signals for 100000 Timesteps")

# %%
import mplfinance as mpf
import matplotlib.dates as mdates
import pandas as pd
import matplotlib.pyplot as plt

# Function to calculate profit based on buy and sell signals
def calculate_profit(buy_signals, sell_signals, df):
    buy_prices = df.loc[buy_signals, 'close']
    sell_prices = df.loc[sell_signals, 'close']

    # Ensure that the number of buy signals is less than or equal to the number of sell signals
    min_length = min(len(buy_prices), len(sell_prices))

    # Calculate profit for each pair of buy and sell signals
    profits = []
    for i in range(min_length):
        profit = sell_prices.iloc[i] - buy_prices.iloc[i]  # Profit = Sell Price - Buy Price
        profits.append(profit)

    total_profit = sum(profits)
    return total_profit, profits

# Function to plot the signals and compare profits
def plot_signals_and_compare_profit(buy_signals, sell_signals, df, title):
    # Convert buy/sell signals to DatetimeIndex
    buy_signals = pd.to_datetime(buy_signals)  
    buy_signals = buy_signals[buy_signals.isin(df.index)]  # Filter buy signals to match df.index

    sell_signals = pd.to_datetime(sell_signals)  
    sell_signals = sell_signals[sell_signals.isin(df.index)]  # Filter sell signals to match df.index

    # Create new columns to mark the buy and sell signals with NaN for non-signals
    buy_signal_prices = df['close'].copy()
    buy_signal_prices[~df.index.isin(buy_signals)] = float('nan')  # Set non-buy signals to NaN

    sell_signal_prices = df['close'].copy()
    sell_signal_prices[~df.index.isin(sell_signals)] = float('nan')  # Set non-sell signals to NaN

    # Create addplots for buy and sell signals
    buy_signal_plot = mpf.make_addplot(buy_signal_prices, type='scatter', markersize=40, marker='^', color='green')
    sell_signal_plot = mpf.make_addplot(sell_signal_prices, type='scatter', markersize=40, marker='v', color='red')

    # Plot with the added buy and sell signals
    fig, axes = mpf.plot(
        df,
        type='ohlc',
        style='charles',
        datetime_format='%Y-%m-%d %H:%M',
        addplot=[buy_signal_plot, sell_signal_plot],
        returnfig=True,
        figsize=(20, 10),
        warn_too_much_data=1000  # Adjust the size again to maintain consistency
    )

    # Customize x-axis
    #axes[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
    #plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    # Add legend manually
    #plt.legend(['Buy Signals', 'Sell Signals'], loc='upper left')

    # Add title
    #plt.title(title)

    # Show the plot
    #plt.show()

    # Calculate and print profit for the signals
    total_profit, profits = calculate_profit(buy_signals, sell_signals, df)
    print(f"Total Profit for {title}: {total_profit:.2f}")
    return total_profit

# Calculate and plot for 1000 timesteps signals
profit_1000 = plot_signals_and_compare_profit(buy_signals_1000, sell_signals_1000, df, title="Profit for 1000 Timesteps")

# Calculate and plot for 10000 timesteps signals
profit_10000 = plot_signals_and_compare_profit(buy_signals_10000, sell_signals_10000, df, title="Profit for 10000 Timesteps")

# Calculate and plot for 100000 timesteps signals
profit_100000 = plot_signals_and_compare_profit(buy_signals_100000, sell_signals_100000, df, title="Profit for 100000 Timesteps")


# Compare the total profits
print(f"Total Profit for 1000 Timesteps: {profit_1000:.2f}")
print(f"Total Profit for 10000 Timesteps: {profit_10000:.2f}")
print(f"Total Profit for 100000 Timesteps: {profit_100000:.2f}")
# Out:
# Total Profit for Profit for 1000 Timesteps: 0.05
# Total Profit for Profit for 10000 Timesteps: -0.18
# Total Profit for Profit for 100000 Timesteps: 0.01
# Total Profit for 1000 Timesteps: 0.05
# Total Profit for 10000 Timesteps: -0.18
# Total Profit for 100000 Timesteps: 0.01
