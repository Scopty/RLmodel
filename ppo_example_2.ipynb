# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=1)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_cartpole")

del model # remove to demonstrate saving and loading

model = PPO.load("ppo_cartpole")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 21.9     |
# | time/              |          |
# |    fps             | 7850     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 27          |
# | time/                   |             |
# |    fps                  | 5019        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008845664 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00502     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.33        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 53.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.1        |
# |    ep_rew_mean          | 36.1        |
# | time/                   |             |
# |    fps                  | 4607        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009386186 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.0887      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | 43.8        |
# | time/                   |             |
# |    fps                  | 4424        |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008523447 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.1        |
# |    ep_rew_mean          | 58.1        |
# | time/                   |             |
# |    fps                  | 4334        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010406038 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 59.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.8         |
# |    ep_rew_mean          | 70.8         |
# | time/                   |              |
# |    fps                  | 4280         |
# |    iterations           | 6            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0060597984 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0157      |
# |    value_loss           | 55.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.2        |
# |    ep_rew_mean          | 87.2        |
# | time/                   |             |
# |    fps                  | 4231        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008498355 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 59.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 4191         |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0057691834 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00687     |
# |    value_loss           | 53.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 4149        |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006380338 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 30.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 4125         |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0034938667 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 53.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 4087        |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012596146 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 17.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 4066        |
# |    iterations           | 12          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006524237 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00824    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 4055        |
# |    iterations           | 13          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008805849 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 57.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 4034         |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0037983677 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.58         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 34.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 4028        |
# |    iterations           | 15          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008690606 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.283       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 3.15        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 4008         |
# |    iterations           | 16           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0069521107 |
# |    clip_fraction        | 0.09         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00756     |
# |    value_loss           | 1.71         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 264          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 3984         |
# |    iterations           | 17           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0029196525 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0822       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 1.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 3979         |
# |    iterations           | 18           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045265183 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.0292       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0315       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.681        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | 295          |
# | time/                   |              |
# |    fps                  | 3965         |
# |    iterations           | 19           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0037351055 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | 0.0287       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00957      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000364    |
# |    value_loss           | 0.428        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 314          |
# |    ep_rew_mean          | 314          |
# | time/                   |              |
# |    fps                  | 3960         |
# |    iterations           | 20           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0038473038 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.523       |
# |    explained_variance   | 0.0781       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0124       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 0.266        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 331          |
# | time/                   |              |
# |    fps                  | 3947         |
# |    iterations           | 21           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0068414686 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.0243       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00982      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.183        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 346          |
# | time/                   |              |
# |    fps                  | 3932         |
# |    iterations           | 22           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0033636717 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0207       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000941    |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 361          |
# | time/                   |              |
# |    fps                  | 3924         |
# |    iterations           | 23           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0049397075 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.0745       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0023      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000585    |
# |    value_loss           | 0.0719       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 376          |
# |    ep_rew_mean          | 376          |
# | time/                   |              |
# |    fps                  | 3920         |
# |    iterations           | 24           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0020803148 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.0451       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0118       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 0.0431       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 391          |
# | time/                   |              |
# |    fps                  | 3919         |
# |    iterations           | 25           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0034392849 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.481       |
# |    explained_variance   | 0.161        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00115     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.0273       |
# ------------------------------------------
# 2025-02-10 21:05:57.702 python3[72471:7274690] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-10 21:05:57.702 python3[72471:7274690] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      19 action, _states = model.predict(obs)
#      20 obs, rewards, dones, info = vec_env.step(action)
# ---> 21 vec_env.render("human")
#
# File ~/jupyter_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:104, in DummyVecEnv.render(self, mode)
#      97 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      98     """
#      99     Gym environment rendering. If there are multiple environments then
#     100     they are tiled together in one image via ``BaseVecEnv.render()``.
#     101
#     102     :param mode: The rendering type.
#     103     """
# --> 104     return super().render(mode=mode)
#
# File ~/jupyter_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:264, in VecEnv.render(self, mode)
#     260 if mode == "human":
#     261     # Display it using OpenCV
#     262     import cv2
# --> 264     cv2.imshow("vecenv", bigimg[:, :, ::-1])
#     265     cv2.waitKey(1)
#     266 else:
#
# KeyboardInterrupt:
